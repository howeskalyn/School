# %%
import numpy as np
import pandas as pd

# %%
# Nxx_kgkm is indexed by (country, crop, year) 
# Need to have these files in the same folder as the notebook, or provide the full path

Nfix_kgkm = np.load('Nfix_kgkm.npy')
Nman_kgkm = np.load('Nman_kgkm.npy')

# %%
Nfix_kgkm.shape
# Out:
# (218, 170, 55)

# %%
df_fix = pd.DataFrame(Nfix_kgkm[0]) # careful! this is just extracting the data for Afghanistan

# %%
df_man = pd.DataFrame(Nman_kgkm[0])

# %%
df_man.describe()
# Out:
#                 0             1            2            3            4   \
# count    30.000000  3.000000e+01    30.000000    30.000000    30.000000
# mean   1366.454307  1.340078e+03  1364.734639  1382.260055  1434.986634
# std       0.000000  2.312607e-13     0.000000     0.000000     0.000000
# min    1366.454307  1.340078e+03  1364.734639  1382.260055  1434.986634
# 25%    1366.454307  1.340078e+03  1364.734639  1382.260055  1434.986634
# 50%    1366.454307  1.340078e+03  1364.734639  1382.260055  1434.986634
# 75%    1366.454307  1.340078e+03  1364.734639  1382.260055  1434.986634
# max    1366.454307  1.340078e+03  1364.734639  1382.260055  1434.986634
#
#                 5            6            7            8            9   \
# count    30.000000    30.000000    30.000000    30.000000    30.000000
# mean   1512.540164  1667.616504  1762.260554  1734.318755  1696.970213
# std       0.000000     0.000000     0.000000     0.000000     0.000000
# ...

# %%
df_man
# Out:
#               0            1            2            3            4   \
# 0            NaN          NaN          NaN          NaN          NaN
# 1            NaN          NaN          NaN          NaN          NaN
# 2            NaN          NaN          NaN          NaN          NaN
# 3    1366.454307  1340.078011  1364.734639  1382.260055  1434.986634
# 4    1366.454307  1340.078011  1364.734639  1382.260055  1434.986634
# 5            NaN          NaN          NaN          NaN          NaN
# 6            NaN          NaN          NaN          NaN          NaN
# 7            NaN          NaN          NaN          NaN          NaN
# 8            NaN          NaN          NaN          NaN          NaN
# 9            NaN          NaN          NaN          NaN          NaN
# 10           NaN          NaN          NaN          NaN          NaN
# 11   1366.454307  1340.078011  1364.734639  1382.260055  1434.986634
# 12           NaN          NaN          NaN          NaN          NaN
# ...

# %%
CoName = pd.DataFrame(np.load('FAOSTAT_CoName_FAO.npy'))

# %%
CoName
# Out:
#                                                0
# 0                                  [Afghanistan]
# 1                                      [Albania]
# 2                                      [Algeria]
# 3                               [American Samoa]
# 4                                       [Angola]
# 5                          [Antigua and Barbuda]
# 6                                    [Argentina]
# 7                                      [Armenia]
# 8                                    [Australia]
# 9                                      [Austria]
# 10                                  [Azerbaijan]
# 11                                     [Bahamas]
# 12                                     [Bahrain]
# 13                                  [Bangladesh]
# 14                                    [Barbados]
# 15                                     [Belarus]
# 16                                     [Belgium]
# 17                          [Belgium-Luxembourg]
# ...
